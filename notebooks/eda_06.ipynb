# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
from typing import Any
sys.path.insert(0, os.path.abspath('..'))

from src.feature_engineer import load_encoder
from src.utils.model_utils import evaulate_model, train_model
from src.utils.visualize_utils import plot_cm, get_avg_fold
from src.utils.math_utils import get_fft_power

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

import torch.nn as nn
import torch
from torch.utils.data import DataLoader, TensorDataset

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler

from scipy.spatial.transform import Rotation

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
raw_path = "../data/raw"
encoder_path = "../models/label_encoder.pkl"

# %%
# load
full_df = pd.merge(
    left=pd.read_csv(os.path.join(raw_path, "train.csv")),
    right=pd.read_csv(os.path.join(raw_path, "train_demographics.csv")),
    on="subject",
    how="left",
)

full_df = full_df.drop(columns=[col for col in full_df.columns if col.startswith("tof_")])

full_df
# Out:
#                    row_id sequence_type sequence_id  sequence_counter  \
# 0       SEQ_000007_000000        Target  SEQ_000007                 0
# 1       SEQ_000007_000001        Target  SEQ_000007                 1
# 2       SEQ_000007_000002        Target  SEQ_000007                 2
# 3       SEQ_000007_000003        Target  SEQ_000007                 3
# 4       SEQ_000007_000004        Target  SEQ_000007                 4
# ...                   ...           ...         ...               ...
# 574940  SEQ_065531_000048    Non-Target  SEQ_065531                48
# 574941  SEQ_065531_000049    Non-Target  SEQ_065531                49
# 574942  SEQ_065531_000050    Non-Target  SEQ_065531                50
# 574943  SEQ_065531_000051    Non-Target  SEQ_065531                51
# 574944  SEQ_065531_000052    Non-Target  SEQ_065531                52
#
#             subject                      orientation  \
# 0       SUBJ_059520  Seated Lean Non Dom - FACE DOWN
# 1       SUBJ_059520  Seated Lean Non Dom - FACE DOWN
# 2       SUBJ_059520  Seated Lean Non Dom - FACE DOWN
# 3       SUBJ_059520  Seated Lean Non Dom - FACE DOWN
# 4       SUBJ_059520  Seated Lean Non Dom - FACE DOWN
# ...             ...                              ...
# 574940  SUBJ_039498  Seated Lean Non Dom - FACE DOWN
# 574941  SUBJ_039498  Seated Lean Non Dom - FACE DOWN
# 574942  SUBJ_039498  Seated Lean Non Dom - FACE DOWN
# 574943  SUBJ_039498  Seated Lean Non Dom - FACE DOWN
# 574944  SUBJ_039498  Seated Lean Non Dom - FACE DOWN
#
#                                          behavior       phase  \
# 0       Relaxes and moves hand to target location  Transition
# 1       Relaxes and moves hand to target location  Transition
# 2       Relaxes and moves hand to target location  Transition
# 3       Relaxes and moves hand to target location  Transition
# 4       Relaxes and moves hand to target location  Transition
# ...                                           ...         ...
# 574940                           Performs gesture     Gesture
# 574941                           Performs gesture     Gesture
# 574942                           Performs gesture     Gesture
# 574943                           Performs gesture     Gesture
# 574944                           Performs gesture     Gesture
#
#                    gesture     acc_x  ...      thm_3      thm_4      thm_5  \
# 0       Cheek - pinch skin  6.683594  ...  29.553024  28.592863  28.310535
# 1       Cheek - pinch skin  6.949219  ...  29.791740  28.663383  28.406172
# 2       Cheek - pinch skin  5.722656  ...  30.090014  28.796087  28.529778
# 3       Cheek - pinch skin  6.601562  ...  29.310717  29.018711  27.402010
# 4       Cheek - pinch skin  5.566406  ...  26.808746  29.408604  27.357603
# ...                    ...       ...  ...        ...        ...        ...
# 574940   Write name on leg  3.503906  ...  27.857061  30.359417  29.501087
# 574941   Write name on leg  3.773438  ...  27.965866  30.417227  29.244358
# 574942   Write name on leg  3.082031  ...  27.893045  30.340141  29.244358
# 574943   Write name on leg  3.964844  ...  28.046608  30.397961  28.868093
# 574944   Write name on leg  4.269531  ...  27.965866  30.424807  28.860228
#
#         adult_child  age  sex  handedness  height_cm  shoulder_to_wrist_cm  \
# 0                 0   12    1           1      163.0                    52
# 1                 0   12    1           1      163.0                    52
# 2                 0   12    1           1      163.0                    52
# 3                 0   12    1           1      163.0                    52
# 4                 0   12    1           1      163.0                    52
# ...             ...  ...  ...         ...        ...                   ...
# 574940            1   30    0           1      186.0                    55
# 574941            1   30    0           1      186.0                    55
# 574942            1   30    0           1      186.0                    55
# 574943            1   30    0           1      186.0                    55
# 574944            1   30    0           1      186.0                    55
#
#         elbow_to_wrist_cm
# 0                    24.0
# 1                    24.0
# 2                    24.0
# 3                    24.0
# 4                    24.0
# ...                   ...
# 574940               30.0
# 574941               30.0
# 574942               30.0
# 574943               30.0
# 574944               30.0
#
# [574945 rows x 28 columns]

# %%
target_gestures = full_df[full_df["sequence_type"] == "Target"]["gesture"].unique()

filtered_df = full_df[full_df["phase"] == "Gesture"]

# feature engineer rot_w r_x, rt_y rotz
# drop na
bad_seq_id = full_df[full_df["rot_w"].isnull()]["sequence_id"].unique()
bad_seq_mask = filtered_df["sequence_id"].isin(bad_seq_id)
filtered_df = filtered_df[~bad_seq_mask]

filtered_df
# Out:
#                    row_id sequence_type sequence_id  sequence_counter  \
# 25      SEQ_000007_000025        Target  SEQ_000007                25
# 26      SEQ_000007_000026        Target  SEQ_000007                26
# 27      SEQ_000007_000027        Target  SEQ_000007                27
# 28      SEQ_000007_000028        Target  SEQ_000007                28
# 29      SEQ_000007_000029        Target  SEQ_000007                29
# ...                   ...           ...         ...               ...
# 574940  SEQ_065531_000048    Non-Target  SEQ_065531                48
# 574941  SEQ_065531_000049    Non-Target  SEQ_065531                49
# 574942  SEQ_065531_000050    Non-Target  SEQ_065531                50
# 574943  SEQ_065531_000051    Non-Target  SEQ_065531                51
# 574944  SEQ_065531_000052    Non-Target  SEQ_065531                52
#
#             subject                      orientation          behavior  \
# 25      SUBJ_059520  Seated Lean Non Dom - FACE DOWN  Performs gesture
# 26      SUBJ_059520  Seated Lean Non Dom - FACE DOWN  Performs gesture
# 27      SUBJ_059520  Seated Lean Non Dom - FACE DOWN  Performs gesture
# 28      SUBJ_059520  Seated Lean Non Dom - FACE DOWN  Performs gesture
# 29      SUBJ_059520  Seated Lean Non Dom - FACE DOWN  Performs gesture
# ...             ...                              ...               ...
# 574940  SUBJ_039498  Seated Lean Non Dom - FACE DOWN  Performs gesture
# 574941  SUBJ_039498  Seated Lean Non Dom - FACE DOWN  Performs gesture
# 574942  SUBJ_039498  Seated Lean Non Dom - FACE DOWN  Performs gesture
# 574943  SUBJ_039498  Seated Lean Non Dom - FACE DOWN  Performs gesture
# 574944  SUBJ_039498  Seated Lean Non Dom - FACE DOWN  Performs gesture
#
#           phase             gesture     acc_x  ...      thm_3      thm_4  \
# 25      Gesture  Cheek - pinch skin  7.027344  ...  29.079510  29.042253
# 26      Gesture  Cheek - pinch skin  6.984375  ...  29.175192  29.120226
# 27      Gesture  Cheek - pinch skin  7.027344  ...  29.131096  29.104778
# 28      Gesture  Cheek - pinch skin  6.488281  ...  29.123035  29.010979
# 29      Gesture  Cheek - pinch skin  6.988281  ...  29.118908  28.964226
# ...         ...                 ...       ...  ...        ...        ...
# 574940  Gesture   Write name on leg  3.503906  ...  27.857061  30.359417
# 574941  Gesture   Write name on leg  3.773438  ...  27.965866  30.417227
# 574942  Gesture   Write name on leg  3.082031  ...  27.893045  30.340141
# 574943  Gesture   Write name on leg  3.964844  ...  28.046608  30.397961
# 574944  Gesture   Write name on leg  4.269531  ...  27.965866  30.424807
#
#             thm_5  adult_child  age  sex  handedness  height_cm  \
# 25      28.541002            0   12    1           1      163.0
# 26      28.313978            0   12    1           1      163.0
# 27      28.361975            0   12    1           1      163.0
# 28      28.306007            0   12    1           1      163.0
# 29      28.489258            0   12    1           1      163.0
# ...           ...          ...  ...  ...         ...        ...
# 574940  29.501087            1   30    0           1      186.0
# 574941  29.244358            1   30    0           1      186.0
# 574942  29.244358            1   30    0           1      186.0
# 574943  28.868093            1   30    0           1      186.0
# 574944  28.860228            1   30    0           1      186.0
#
#         shoulder_to_wrist_cm  elbow_to_wrist_cm
# 25                        52               24.0
# 26                        52               24.0
# 27                        52               24.0
# 28                        52               24.0
# 29                        52               24.0
# ...                      ...                ...
# 574940                    55               30.0
# 574941                    55               30.0
# 574942                    55               30.0
# 574943                    55               30.0
# 574944                    55               30.0
#
# [254179 rows x 28 columns]

# %%
gesture_length = filtered_df.groupby('sequence_id')['sequence_counter'].max() - filtered_df.groupby('sequence_id')['sequence_counter'].min() + 1

plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.plot(np.arange(len(gesture_length)), gesture_length, 'ro')
plt.title("length of gesture")

plt.subplot(132)
mask = gesture_length >= 35
weird_indices = filtered_df.groupby('sequence_id')['sequence_counter'].max()[mask].index
weird_idx = weird_indices[0]
weird_seq = filtered_df[filtered_df['sequence_id'] == weird_idx]['rot_y']
plt.plot(np.arange(len(weird_seq)), weird_seq, 'b')
plt.title(filtered_df[filtered_df['sequence_id'] == weird_idx]['gesture'].unique()[0])
full_df[full_df['sequence_id'] == "SEQ_014205"]

plt.subplot(133)
gestures = filtered_df[filtered_df['sequence_id'].isin(weird_indices)]['gesture']
plt.hist(gestures)
plt.xticks(rotation=90)
plt.title("gesture to count distribution")

unique_subjects = filtered_df[filtered_df['sequence_id'].isin(weird_indices)]
# print('unique subjects: ', unique_subjects['subject'].unique())
mask = gesture_length < 28
weird_indices = filtered_df.groupby('sequence_id')['sequence_counter'].max()[mask].index

print(len(weird_indices))
# Out:
# 229

# %%
gesture_length = filtered_df.groupby('sequence_id')['sequence_counter'].max()

plt.figure(figsize=(15, 5))
plt.subplot(121)
plt.plot(np.arange(len(gesture_length)), gesture_length, 'ro')
gesture_length.max()

mask = filtered_df.groupby('sequence_id')['sequence_counter'].max() >= 500
weird_idx = filtered_df.groupby('sequence_id')['sequence_counter'].max()[mask].index

plt.subplot(122)
weird_seq = filtered_df[filtered_df['sequence_id'] == weird_idx[0]]['acc_x']
plt.plot(np.arange(len(weird_seq)), weird_seq, 'b')
full_df[full_df['sequence_id'] == "SEQ_014205"][['sequence_id', 'sequence_counter', 'phase']]
# Out:
#        sequence_id  sequence_counter       phase
# 125669  SEQ_014205                 0  Transition
# 125670  SEQ_014205                 1  Transition
# 125671  SEQ_014205                 2  Transition
# 125672  SEQ_014205                 3  Transition
# 125673  SEQ_014205                 4  Transition
# ...            ...               ...         ...
# 126335  SEQ_014205               666     Gesture
# 126336  SEQ_014205               667     Gesture
# 126337  SEQ_014205               668     Gesture
# 126338  SEQ_014205               669     Gesture
# 126339  SEQ_014205               670     Gesture
#
# [671 rows x 3 columns]

# %%
There is clearly people where something went wrong during there experience that they had to shut it down early, below 6 isnt' even acceptable
